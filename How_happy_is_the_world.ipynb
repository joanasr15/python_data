# %% [markdown]
# <a href="https://colab.research.google.com/github/joanasr15/python_data/blob/main/How_happy_is_the_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How happy is the world?
#
# ![HappinessImage-Benjamin Scott](https://drive.google.com/uc?id=1wWdXTclLAjPpZUiKkR8XGg0Sl7iD1u8T)
#
# (Image by Benjamin Scott, [source](https://www.natureindex.com/news-blog/data-visualization-these-are-the-happiest-countries-world-happiness-report-twenty-nineteen))
#
# The Sustainable Development Solutions Network (SDSN) collects data across the world relating to happiness.  They use this data to rank countries in order of happiness factor.
#
# This is not an exact science but can give food for thought in terms of what factors might have the most impact on a nation's happiness levels.
#
# Data is taken from the Gallup World Poll, so not collected directly by SDSN.
# Countries are grouped by region.
#
# ### The factors included are:
# Economy (measured in GDP per Capita)
# Family (support systems)
# Health (measured by Life Expectancy)
# Freedom (sense of)
# Trust (Government Corruption)
# Generosity (charitable inclinations)
# Dystopia Residual
# *  Dystopic is the theoretical most unhappy country with the lowest levels in all six of the above factors
# *  The Residual measure is a calculated as the average of the six distances from lowest
#
# Let's take a look at the data

# %% [markdown]
# ---
# ### Open a data set
#
# Open the data set, an Excel file with only one sheet (so sheet_name is not necessary) from here: https://github.com/futureCodersSE/working-with-data/blob/main/Happiness-Data/2015.xlsx?raw=true
#
# Interrogate the data (head, tail, iloc) to get to know what it contains.

# %%
import pandas as pd

#Open the data set, an Excel file with only one sheet (so sheet_name is not necessary) from here: https://github.com/futureCodersSE/working-with-data/blob/main/Happiness-Data/2015.xlsx?raw=true

url = "https://github.com/futureCodersSE/working-with-data/blob/main/Happiness-Data/2015.xlsx?raw=true"

happiness = pd.read_excel(url)

#Interrogate the data (head, tail, iloc) to get to know what it contains.

display(happiness.head())

print("\n")

display(happiness.tail())

print("\n")

display(happiness.iloc[:5])
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 153     0.22628            0.67042
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# 157     0.16681            1.56726
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %% [markdown]
# ---
# ### Sort the data in different ways
#
# The data is currently sorted in order of rank.  To sort the data in the table, run the code below, which identifies the column on which to sort in the brackets.
#
# Then, **try sorting on other columns** *Note: you must type the column heading in the quotes and exactly as it appears in the table (including capitalisation)*.  To sort on multiple columns, enter a list of column headings in the brackets (e.g. `.sort_values(['Region','Freedom'])`

# %%
import pandas as pd

url = "https://github.com/futureCodersSE/working-with-data/blob/main/Happiness-Data/2015.xlsx?raw=true"

happiness = pd.read_excel(url)

sorted_table = happiness.sort_values(['Family'])
display(sorted_table)  # output the table below

print("Sorted by Economy (GDP per Capita):")

sorted_by_economy = happiness.sort_values('Economy (GDP per Capita)')

display(sorted_by_economy)

print("\nSorted by Region and Freedom:")

sorted_by_region_freedom = happiness.sort_values(['Region', 'Freedom'])

display(sorted_by_region_freedom)
# Out:
#                       Country                      Region  Happiness Rank  \
# 147  Central African Republic          Sub-Saharan Africa             148
# 157                      Togo          Sub-Saharan Africa             158
# 152               Afghanistan               Southern Asia             153
# 154                     Benin          Sub-Saharan Africa             155
# 116                     India               Southern Asia             117
# ..                        ...                         ...             ...
# 43                 Uzbekistan  Central and Eastern Europe              44
# 0                 Switzerland              Western Europe               1
# 2                     Denmark              Western Europe               3
# 17                    Ireland              Western Europe              18
# 1                     Iceland              Western Europe               2
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 147            3.678         0.06112                   0.07850  0.00000
# 157            2.839         0.06727                   0.20868  0.13995
# 152            3.575         0.03084                   0.31982  0.30285
# 154            3.340         0.03656                   0.28665  0.35386
# 116            4.565         0.02043                   0.64499  0.38174
# ..               ...             ...                       ...      ...
# 43             6.003         0.04361                   0.63244  1.34043
# 0              7.587         0.03411                   1.39651  1.34951
# 2              7.527         0.03328                   1.32548  1.36058
# 17             6.940         0.03676                   1.33596  1.36948
# 1              7.561         0.04884                   1.30232  1.40223
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 147                   0.06699  0.48879                        0.08289
# 157                   0.28443  0.36453                        0.10731
# 152                   0.30335  0.23414                        0.09719
# 154                   0.31910  0.48450                        0.08010
# 116                   0.51529  0.39786                        0.08492
# ..                        ...      ...                            ...
# 43                    0.59772  0.65821                        0.30826
# 0                     0.94143  0.66557                        0.41978
# 2                     0.87464  0.64938                        0.48357
# 17                    0.89533  0.61777                        0.28703
# 1                     0.94784  0.62877                        0.14145
#
#      Generosity  Dystopia Residual
# 147     0.23835            2.72230
# 157     0.16681            1.56726
# 152     0.36510            1.95210
# 154     0.18260            1.63328
# 116     0.26475            2.27513
# ..          ...                ...
# 43      0.22837            2.23741
# 0       0.29678            2.51738
# 2       0.34139            2.49204
# 17      0.45901            1.97570
# 1       0.43630            2.70201
#
# [158 rows x 12 columns]
# Sorted by Economy (GDP per Capita):
#               Country                           Region  Happiness Rank  \
# 119  Congo (Kinshasa)               Sub-Saharan Africa             120
# 156           Burundi               Sub-Saharan Africa             157
# 130            Malawi               Sub-Saharan Africa             131
# 143             Niger               Sub-Saharan Africa             144
# 115           Liberia               Sub-Saharan Africa             116
# ..                ...                              ...             ...
# 3              Norway                   Western Europe               4
# 23          Singapore                Southeastern Asia              24
# 38             Kuwait  Middle East and Northern Africa              39
# 16         Luxembourg                   Western Europe              17
# 27              Qatar  Middle East and Northern Africa              28
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 119            4.517         0.03680                   0.00000  1.00120
# 156            2.905         0.08658                   0.01530  0.41587
# 130            4.292         0.06130                   0.01604  0.41134
# 143            3.845         0.03602                   0.06940  0.77265
# 115            4.571         0.11068                   0.07120  0.78968
# ..               ...             ...                       ...      ...
# 3              7.522         0.03880                   1.45900  1.33095
# 23             6.798         0.03780                   1.52186  1.02000
# 38             6.295         0.04456                   1.55422  1.16594
# 16             6.946         0.03499                   1.56391  1.21963
# 27             6.611         0.06257                   1.69042  1.07860
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 119                   0.09806  0.22605                        0.07625
# 156                   0.22396  0.11850                        0.10062
# 130                   0.22562  0.43054                        0.06977
# 143                   0.29707  0.47692                        0.15639
# 115                   0.34201  0.28531                        0.06232
# ..                        ...      ...                            ...
# 3                     0.88521  0.66973                        0.36503
# 23                    1.02525  0.54252                        0.49210
# 38                    0.72492  0.55499                        0.25609
# 16                    0.91894  0.61583                        0.37798
# 27                    0.79733  0.64040                        0.52208
#
#      Generosity  Dystopia Residual
# 119     0.24834            2.86712
# 156     0.19727            1.83302
# 130     0.33128            2.80791
# 143     0.19387            1.87877
# 115     0.24362            2.77729
# ..          ...                ...
# 3       0.34699            2.46531
# 23      0.31105            1.88501
# 38      0.16228            1.87634
# 16      0.28034            1.96961
# 27      0.32573            1.55674
#
# [158 rows x 12 columns]
# Sorted by Region and Freedom:
#                     Country                      Region  Happiness Rank  \
# 8               New Zealand   Australia and New Zealand               9
# 9                 Australia   Australia and New Zealand              10
# 95   Bosnia and Herzegovina  Central and Eastern Europe              96
# 82               Montenegro  Central and Eastern Europe              82
# 126                 Armenia  Central and Eastern Europe             127
# ..                      ...                         ...             ...
# 5                   Finland              Western Europe               6
# 2                   Denmark              Western Europe               3
# 7                    Sweden              Western Europe               8
# 0               Switzerland              Western Europe               1
# 3                    Norway              Western Europe               4
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 8              7.286         0.03371                   1.25018  1.31967
# 9              7.284         0.04083                   1.33358  1.30923
# 95             4.949         0.06913                   0.83223  0.91916
# 82             5.192         0.05235                   0.97438  0.90557
# 126            4.350         0.04763                   0.76821  0.77711
# ..               ...             ...                       ...      ...
# 5              7.406         0.03140                   1.29025  1.31826
# 2              7.527         0.03328                   1.32548  1.36058
# 7              7.364         0.03157                   1.33171  1.28907
# 0              7.587         0.03411                   1.39651  1.34951
# 3              7.522         0.03880                   1.45900  1.33095
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 8                     0.90837  0.63938                        0.42922
# 9                     0.93156  0.65124                        0.35637
# 95                    0.79081  0.09245                        0.00227
# 82                    0.72521  0.18260                        0.14296
# 126                   0.72990  0.19847                        0.03900
# ..                        ...      ...                            ...
# 5                     0.88911  0.64169                        0.41372
# 2                     0.87464  0.64938                        0.48357
# 7                     0.91087  0.65980                        0.43844
# 0                     0.94143  0.66557                        0.41978
# 3                     0.88521  0.66973                        0.36503
#
#      Generosity  Dystopia Residual
# 8       0.47501            2.26425
# 9       0.43562            2.26646
# 95      0.24808            2.06367
# 82      0.16140            2.10017
# 126     0.07855            1.75873
# ..          ...                ...
# 5       0.23351            2.61955
# 2       0.34139            2.49204
# 7       0.36262            2.37119
# 0       0.29678            2.51738
# 3       0.34699            2.46531
#
# [158 rows x 12 columns]

# %% [markdown]
# ---
# ### Summarising the data
#
# Look at the happiness dataframe.  Create new dataframes from a range of rows, columns, statistical information, etc.
#
# For each dataframe, add a text cell to explain what it is showing

# %%
import pandas as pd

url = "https://github.com/futureCodersSE/working-with-data/blob/main/Happiness-Data/2015.xlsx?raw=true"

happiness = pd.read_excel(url)

# Subset of Rows and Columns

print("Subset of Rows and Columns: \n")

subset_df = happiness.loc[:4, ['Country', 'Region', 'Happiness Rank', 'Economy (GDP per Capita)', 'Health (Life Expectancy)']]

display(subset_df)

# Summary Statistics

print("\n Summary Statistics: \n")

summary_stats_df = happiness.describe()

display(summary_stats_df)

# Countries in a Specific Region - 'Western Europe'

print("\n Countries in a Specific Region - 'Western Europe': \n")

specific_region_df = happiness[happiness['Region'] == 'Western Europe']

display(specific_region_df)

# Top N Happiest Countries - top 10

print("\n Top N Happiest Countries - top 10: \n")

top_10_happy_df = happiness.head(10)

display(top_10_happy_df)
# Out:
# Subset of Rows and Columns:
#        Country          Region  Happiness Rank  Economy (GDP per Capita)  \
# 0  Switzerland  Western Europe               1                   1.39651
# 1      Iceland  Western Europe               2                   1.30232
# 2      Denmark  Western Europe               3                   1.32548
# 3       Norway  Western Europe               4                   1.45900
# 4       Canada   North America               5                   1.32629
#
#    Health (Life Expectancy)
# 0                   0.94143
# 1                   0.94784
# 2                   0.87464
# 3                   0.88521
# 4                   0.90563
#  Summary Statistics:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# 50%                    0.910245    1.029510                  0.696705
# 75%                    1.158448    1.214405                  0.811013
# max                    1.690420    1.402230                  1.025250
#
#           Freedom  Trust (Government Corruption)  Generosity  \
# count  158.000000                     158.000000  158.000000
# mean     0.428615                       0.143422    0.237296
# std      0.150693                       0.120034    0.126685
# min      0.000000                       0.000000    0.000000
# 25%      0.328330                       0.061675    0.150553
# 50%      0.435515                       0.107220    0.216130
# 75%      0.549092                       0.180255    0.309883
# max      0.669730                       0.551910    0.795880
#
#        Dystopia Residual
# count         158.000000
# mean            2.098977
# std             0.553550
# min             0.328580
# 25%             1.759410
# 50%             2.095415
# 75%             2.462415
# max             3.602140
#  Countries in a Specific Region - 'Western Europe':
#             Country          Region  Happiness Rank  Happiness Score  \
# 0       Switzerland  Western Europe               1            7.587
# 1           Iceland  Western Europe               2            7.561
# 2           Denmark  Western Europe               3            7.527
# 3            Norway  Western Europe               4            7.522
# 5           Finland  Western Europe               6            7.406
# 6       Netherlands  Western Europe               7            7.378
# 7            Sweden  Western Europe               8            7.364
# 12          Austria  Western Europe              13            7.200
# 16       Luxembourg  Western Europe              17            6.946
# 17          Ireland  Western Europe              18            6.940
# 18          Belgium  Western Europe              19            6.937
# 20   United Kingdom  Western Europe              21            6.867
# 25          Germany  Western Europe              26            6.750
# 28           France  Western Europe              29            6.575
# 35            Spain  Western Europe              36            6.329
# 36            Malta  Western Europe              37            6.302
# 49            Italy  Western Europe              50            5.948
# 65     North Cyprus  Western Europe              66            5.695
# 66           Cyprus  Western Europe              67            5.689
# 87         Portugal  Western Europe              88            5.102
# 101          Greece  Western Europe             102            4.857
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# 2           0.03328                   1.32548  1.36058
# 3           0.03880                   1.45900  1.33095
# 5           0.03140                   1.29025  1.31826
# 6           0.02799                   1.32944  1.28017
# 7           0.03157                   1.33171  1.28907
# 12          0.03751                   1.33723  1.29704
# 16          0.03499                   1.56391  1.21963
# 17          0.03676                   1.33596  1.36948
# 18          0.03595                   1.30782  1.28566
# 20          0.01866                   1.26637  1.28548
# 25          0.01848                   1.32792  1.29937
# 28          0.03512                   1.27778  1.26038
# 35          0.03468                   1.23011  1.31379
# 36          0.04206                   1.20740  1.30203
# 49          0.03914                   1.25114  1.19777
# 65          0.05635                   1.20806  1.07008
# 66          0.05580                   1.20813  0.89318
# 87          0.04802                   1.15991  1.13935
# 101         0.05062                   1.15406  0.92933
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 5                     0.88911  0.64169                        0.41372
# 6                     0.89284  0.61576                        0.31814
# 7                     0.91087  0.65980                        0.43844
# 12                    0.89042  0.62433                        0.18676
# 16                    0.91894  0.61583                        0.37798
# 17                    0.89533  0.61777                        0.28703
# 18                    0.89667  0.58450                        0.22540
# 20                    0.90943  0.59625                        0.32067
# 25                    0.89186  0.61477                        0.21843
# 28                    0.94579  0.55011                        0.20646
# 35                    0.95562  0.45951                        0.06398
# 36                    0.88721  0.60365                        0.13586
# 49                    0.95446  0.26236                        0.02901
# 65                    0.92356  0.49027                        0.14280
# 66                    0.92356  0.40672                        0.06146
# 87                    0.87519  0.51469                        0.01078
# 101                   0.88213  0.07699                        0.01397
#
#      Generosity  Dystopia Residual
# 0       0.29678            2.51738
# 1       0.43630            2.70201
# 2       0.34139            2.49204
# 3       0.34699            2.46531
# 5       0.23351            2.61955
# 6       0.47610            2.46570
# 7       0.36262            2.37119
# 12      0.33088            2.53320
# 16      0.28034            1.96961
# 17      0.45901            1.97570
# 18      0.22250            2.41484
# 20      0.51912            1.96994
# 25      0.28214            2.11569
# 28      0.12332            2.21126
# 35      0.18227            2.12367
# 36      0.51752            1.64880
# 49      0.22823            2.02518
# 65      0.26169            1.59888
# 66      0.30638            1.88931
# 87      0.13719            1.26462
# 101     0.00000            1.80101
#  Top N Happiest Countries - top 10:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
# 5         0.03140                   1.29025  1.31826
# 6         0.02799                   1.32944  1.28017
# 7         0.03157                   1.33171  1.28907
# 8         0.03371                   1.25018  1.31967
# 9         0.04083                   1.33358  1.30923
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
# 5                   0.88911  0.64169                        0.41372
# 6                   0.89284  0.61576                        0.31814
# 7                   0.91087  0.65980                        0.43844
# 8                   0.90837  0.63938                        0.42922
# 9                   0.93156  0.65124                        0.35637
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176
# 5     0.23351            2.61955
# 6     0.47610            2.46570
# 7     0.36262            2.37119
# 8     0.47501            2.26425
# 9     0.43562            2.26646

# %% [markdown]
# ---
# ### Next steps
#
# There are data sets for the years 2015 to 2019 available.  To access and try out other years, change 2015 to the required year in the URL in the first code cell.  Leave the rest exactly as it is.
#
# Other years may have different column headings and so there will be different data to play with.
